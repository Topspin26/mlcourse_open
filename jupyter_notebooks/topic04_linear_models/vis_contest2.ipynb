# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("dark")
from tqdm import tqdm_notebook
import pandas as pd
from collections import defaultdict

# поменяйте на свой путь
DS_FILE_NAME = '../../data/data.hw4/stackoverflow_sample_125k.tsv'
TAGS_FILE_NAME = '../../data/data.hw4/top10_tags.tsv'

# %% [markdown]
# ## Tag-Tag affinity

# %%
top_tags = []
with open(TAGS_FILE_NAME, 'r') as f:
    for line in f:
        top_tags.append(line.strip())
top_tags = sorted(top_tags)
print(top_tags)
n_tags = len(top_tags)

tag2num = dict(zip(top_tags, range(n_tags)))
num2tag = dict(zip(range(n_tags), sorted(top_tags)))

df = pd.read_csv(DS_FILE_NAME, sep = '\t', header = None)

sum_tags = np.zeros((n_tags, n_tags))
for e in df[1]:
    tags = sorted(e.split(' '))
    for i1 in range(len(tags)):
        for i2 in range(i1, len(tags)):
            sum_tags[tag2num[tags[i1]], tag2num[tags[i2]]] += 1
sum_tags = (sum_tags + sum_tags.T - np.diag(np.diag(sum_tags)))
d_tags = np.zeros((n_tags, n_tags))
for i in range(n_tags):
    for j in range(n_tags):
        if i != j:
            d_tags[i, j] = (sum_tags[i, j] / sum_tags[i, i]) * (sum_tags[i, j] / sum_tags[j, j])
        else:
            d_tags[i, j] = np.nan

plt.figure(figsize=(6, 4))
ax = sns.heatmap(pd.DataFrame(d_tags**0.5, index=top_tags, columns=top_tags), annot=True, fmt=".1f", linewidths=.5)
plt.title('Tag-Tag affinity')
plt.tight_layout()
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

plt.savefig('tag_tag_affinity.png')
plt.show()
# Out:
# ['android', 'c#', 'c++', 'html', 'ios', 'java', 'javascript', 'jquery', 'php', 'python']

# %% [markdown]
# ## Words-Tag affinity

# %% [markdown]
# ### Extract most frequent words

# %%
from collections import Counter
cw = Counter()
for e in df[0]:
    cw.update(e.split(' '))

n_words = 1000
freq_words = sorted([e[0] for e in sorted(cw.items(), key=lambda x: -x[1])[:n_words]])

word2num = dict(zip(freq_words, range(n_words)))
num2word = dict(zip(range(n_words), freq_words))
freq_words_set = set(freq_words)

# %% [markdown]
# ### Word-Word affinity

# %%
sum_words = np.zeros((n_words, n_words))
for e in tqdm_notebook(df[0], total=len(df)):
    words = list(set(e.split(' ')) & freq_words_set)
    for i1 in range(len(words)):
        for i2 in range(i1, len(words)):
            sum_words[word2num[words[i1]], word2num[words[i2]]] += 1
sum_words = (sum_words + sum_words.T - np.diag(np.diag(sum_words)))

# %% [markdown]
# ### Words clustering

# %%
d_words = np.zeros((n_words, n_words))
for i in range(n_words):
    for j in range(n_words):
        d_words[i, j] = (sum_words[i, j] / sum_words[i, i]) * (sum_words[i, j] / sum_words[j, j])
        
from sklearn.cluster import SpectralClustering
n_clusters = 100
cl = SpectralClustering(n_clusters=n_clusters, affinity='precomputed', random_state=7)
y = cl.fit_predict(d_words)

order = []
dens = []
word_clusters = []
for j in range(n_clusters):
    dens.append(np.mean(d_words[np.where(y == j)][:,np.where(y == j)]))
for j in np.argsort(-np.array(dens)):
    print([j, dens[j]], end = ': ')
    cluster = set()
    for i in range(len(y)):
        if y[i] == j:
            print(num2word[i], end=' ')
            order.append(i)
            cluster.add(num2word[i])
    word_clusters.append(cluster)
    print()
    print()
# Out:
# [39, 1.0]: 0
#
# [95, 1.0]: help
#
# [66, 1.0]: document
#
# [5, 1.0]: t
#
# [73, 1.0]: file
#
# [91, 0.92085115604503365]:  i the to
#
# [96, 0.89304697986577186]: artifactid groupid
#
# [40, 0.88826705518298721]: gt lt
#
# [59, 0.84768479785162909]: li ul
#
# [24, 0.83185307233267469]: td tr
#
# [6, 0.81736752248284561]: layoutinflater viewgroup
#
# [20, 0.78178290561499697]: height width
#
# [11, 0.76906873624910843]: bundle oncreate savedinstancestate
#
# [12, 0.66442856144846896]: +id layout_height layout_width linearlayout match_parent wrap_content
#
# [21, 0.63546851034492435]: x y
#
# [69, 0.62904105668697419]: function var
#
# [13, 0.61730135768238492]: console log
#
# [46, 0.61024045707210162]: cout endl std
#
# [27, 0.6071067138375752]: advance thanks
#
# [71, 0.60222243113374763]: bin usr
#
# [19, 0.60112651878000889]: 1px border solid
#
# [49, 0.58613957981307585]: button click
#
# [30, 0.55638321633251053]: our we
#
# [54, 0.54948324096137036]: private public void
#
# [82, 0.547775611829458]: bar foo
#
# [10, 0.5461824893788908]: 1 2 3
#
# [9, 0.53604629027304251]: a and but have in is it my of this
#
# [85, 0.52620745514411982]: func let
#
# [42, 0.51173262613899084]: awt javax swing
#
# [3, 0.49378542449450424]: com http www
#
# [44, 0.4931581815880115]: catch exception try
#
# [70, 0.47988082002309074]: angular ng scope
#
# [60, 0.47730999745601632]: alloc nil nsstring
#
# [99, 0.47555607737632738]: alt img src
#
# [26, 0.47372104435257695]: apk drawable res schemas xmlns
#
# [33, 0.45924564368654902]: login password username
#
# [15, 0.45076506705332758]: auto generated todo
#
# [92, 0.43410702644310445]: align center font
#
# [64, 0.43049424655919916]: break case switch
#
# [14, 0.42339914253087585]: activitythread androidruntime handler internal invoke reflect zygoteinit
#
# [77, 0.41186338201403483]: bean beans spring springframework
#
# [35, 0.40765545971697242]: asp jsfiddle net
#
# [76, 0.40363110512360695]: + i++ length
#
# [31, 0.38554939028585616]: e object sender
#
# [37, 0.38372032075166879]: item items list
#
# [68, 0.38356988517608326]: google map maps
#
# [25, 0.38013010912898948]: findviewbyid layout r settext textview
#
# [55, 0.38010028229342957]: email mail send
#
# [56, 0.37980772745603336]: django model models
#
# [65, 0.36923857177407149]: _post echo isset php
#
# [72, 0.36668054653301013]: child children parent
#
# [18, 0.36274342226289269]: css href link rel
#
# [63, 0.35896551550939804]: browser chrome ie
#
# [36, 0.35846870047087054]: action form input submit
#
# [2, 0.35716753547401386]: can do for how want
#
# [47, 0.35560583448945077]: body head meta title
#
# [53, 0.35420582242001353]: any appreciated be would
#
# [8, 0.34099628715281388]: 8 encoding utf version xml
#
# [78, 0.32804095557409485]: ajax jquery js min
#
# [48, 0.32728431381208817]: image images jpg png
#
# [58, 0.32665906491884855]: am doing what wrong
#
# [51, 0.32584717347008579]: from query select where
#
# [62, 0.32471574748967347]: import java package util
#
# [16, 0.32433825108220432]: else false if return true
#
# [7, 0.32030114589173869]: me please thank you
#
# [81, 0.31677552606337217]: io ioexception printstacktrace throws
#
# [67, 0.30359926493548145]: 4 5 6 7 9
#
# [45, 0.30306951241583246]: like or so that there way
#
# [4, 0.30269736959463006]: int new null string tostring
#
# [32, 0.30088193398866586]: def print python self
#
# [79, 0.29700697403508558]: doesn don know work
#
# [50, 0.29582607501323566]: adapter arraylist getstring listview
#
# [28, 0.27666333048791025]: args main out println static system
#
# [61, 0.27631420410604535]: load loaded loading page
#
# [43, 0.2637457057399798]: background black color red white
#
# [74, 0.25501220775410133]: column columns row rows table
#
# [17, 0.2547549375799259]: getelementbyid html javascript ready script
#
# [29, 0.22877510947176688]: boolean class extends final implements override protected super
#
# [88, 0.22659343260677503]: directory filename files folder path
#
# [89, 0.21828289142931984]: 00 date datetime format time
#
# [97, 0.21272879580717038]: last lib module most packages py
#
# [0, 0.20995801694472457]: 0px bottom left margin padding position right top
#
# [34, 0.20015705048450058]: data json post request response success url
#
# [93, 0.19905638452538754]: div h1 h2 h3 p span
#
# [83, 0.19886041953644581]: activity android app device mainactivity os widget
#
# [52, 0.18860978712222864]: at lang native run sun thread unknown
#
# [80, 0.17491647336440577]: 11 12 13 14 15 16 17 18 19
#
# [84, 0.16966022422033283]: 10 100 20 30 40 50 60
#
# [90, 0.15963483895018107]: build compile eclipse jar plugin project release
#
# [98, 0.14187104233823092]: conn connect connection database db insert localhost mysql sql
#
# [86, 0.14091226702112516]: category filter icon intent label permission sdk uses
#
# [22, 0.13521173150053825]: an as code error following get getting here id line method name not text trying type using value with
#
# [57, 0.13105053545679565]: 21 22 23 24 25 26 27 28 29 31 32
#
# [41, 0.12613915577551499]: after fine first on one only problem same second then two when works
#
# [87, 0.12044844276118778]: buffer byte bytes close open read stream txt while write
#
# [75, 0.072631333946827789]: b c cpp d f g h include j k l n o q u v w
#
# [38, 0.04487771717038299]: about all another are best better between both by different each etc every example has into make many may more multiple need now number other possible question say should some such than their them these they those use used user which will
#
# [1, 0.026175166450302559]: able actually also answer anyone anything around because been before being bit could did didn does edit either even everything far few figure find found going got had having however ideas isn issue just looking looks m might missing much no nothing point really s see seem seems simple since solution someone something still sure thing things think though tried understand up ve very was well why working
#
# [94, 0.017251312808696236]: access add apache api application base buttons call called calling calls cannot catalina classes client common component config configuration constructor container context controller core create created custom default defined entity event events factory fragment framework handle hibernate host https implement implementation init instance interface max menu methods objects option options org param parameter parameters pass pattern port properties property reference resource resources rest root security selected server service services servlet set support test throw ui view views web
#
# [23, 0.0041184364790368194]: 01 02 03 04 05 06 07 08 09 1000 200 2013 2014 2015 2016 255 500 _ above account achieve active added adding address admin again alert allow already always amount amp animation append area array attr attribute available back based basic basically below bind binding bitmap block bool boost bootstrap box br btn builder c++ cache calendar callback camera canvas cell ch change changed changes char character check checkbox checked clear clicked col collection command comment const contact contains content contents control convert copy correct correctly count creating csv current currently cursor day debug define delete dependency description details dialog display displayed dll domain done double down download draw driver edittext element elements empty en end enter entry equals err errors ex except execute exists exit expected facebook failed field fields fill fix float follows foreach forms frame full functions game generate gets give given gives global go good grid group happens header headers hello hidden hide home hover idea im imageview index info information inside install installed instead integer invalid ios its join keep key kind language level library lines links local location long look loop lot made making match math maven maybe media memory message messages microsoft mobile modal mode month move msg must names namespace nav nbsp needs never next node non none normal note numbers obj off ok once onclick order original output over own pages panel params parse part pdf person phone place placeholder play player points previous price problems process product program properly push put questions radio random range re reader reading reason record remove render replace require required result results returned returns role running runtime sample save screen scroll search seconds section session setting settings setup show shown shows side similar simply single site size small socket solve sort source space specific split stack start started state statement status step stop store stored str strong struct structure studio stuff style sub successfully tab tableview tag tags take takes target task tell temp template testing textarea textbox th three through times toast token too tools total transform types unable undefined under until update updated upload uri users val valid values variable variables vector via video visible warning website whole window windows within without wondering word writing written year yes your z

# %% [markdown]
# ### Calculate Cluster(Words)-Tag affinity

# %%
sum_tag_cluster = np.zeros((n_tags, n_clusters))
sum_tags = np.zeros((n_tags, 1))
sum_clusters = np.zeros((n_clusters, 1))
for text, tag in tqdm_notebook(zip(df[0], df[1]), total=len(df)):
    tags = tag.split(' ')
    words = set(text.split(' ')) & freq_words_set
    clusters = [i for i in range(n_clusters) if len(word_clusters[i] & words) > 0]
    for i in clusters:
        sum_clusters[i] += 1
    for tag in tags:
        sum_tags[tag2num[tag]] += 1
        for i in clusters:
            sum_tag_cluster[tag2num[tag], i] += 1
            
d_tag_cluster = np.zeros((n_tags, n_clusters))
for i in range(n_tags):
    for j in range(n_clusters):
        d_tag_cluster[i, j] = (sum_tag_cluster[i, j] / sum_clusters[j])
        
ind = d_tag_cluster.max(axis=0) >= 0.33
columns = [', '.join(sorted(list(word_clusters[i]))) for i in range(n_clusters) if i in np.where(ind)[0]]


d_tag_cluster_ind = d_tag_cluster[:, ind]
order = np.argsort(d_tag_cluster_ind.max(axis=0))[::-1]
columns_order = [columns[order[i]] for i in range(len(order))]

fig = plt.figure(figsize=(8, 10))
ax = sns.heatmap(pd.DataFrame(d_tag_cluster_ind[:, order], index=top_tags, columns=columns_order).transpose(), 
                 annot=True, fmt=".1f", linewidths=.5)
plt.title('Words-Tag affinity', y=1.05)
ax.xaxis.tick_top()

plt.savefig('words_tag_affinity.png', bbox_inches='tight')   
plt.show()
